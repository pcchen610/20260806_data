# %% [markdown]
# # XGBoost測試

# %%
#%pip install xgboost -U

# %% [markdown]
# ## 載入相關套件

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np

# %% [markdown]
# ## 載入資料集

# %%
# X, y = datasets.load_diabetes(return_X_y=True)

# %%
X, y = datasets.fetch_california_housing(return_X_y=True)

# %%
#X = X[:, :5]

# %%
print(X.shape)
# Out:
# (20640, 8)

# %% [markdown]
# ## 資料分割

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %% [markdown]
# ## 模型訓練

# %%
from xgboost import XGBRegressor

model = XGBRegressor()
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~\Downloads\20260806_data-main (1)\20260806_data-main\20260730_code\.venv\Lib\site-packages\sklearn\utils\_repr_html\base.py:163, in ReprHTMLMixin._repr_mimebundle_(self, **kwargs)
#     161 output = {"text/plain": repr(self)}
#     162 if get_config()["display"] == "diagram":
# --> 163     output["text/html"] = self._html_repr()
#     164 return output
#
# File ~\Downloads\20260806_data-main (1)\20260806_data-main\20260730_code\.venv\Lib\site-packages\sklearn\utils\_repr_html\estimator.py:564, in estimator_html_repr(estimator)
#     554 _write_estimator_html(
#     555     out,
#     556     estimator,
#    (...)    561     is_fitted_icon=is_fitted_icon,
#     562 )
#     563 with open(str(Path(__file__).parent / "estimator.js"), "r") as f:
# --> 564     script = f.read()
#     566 html_end = (
#     567     f"</div></div><script>{script}"
#     568     f"\nforceTheme('{container_id}');</script></body>"
#     569 )
#     571 out.write(html_end)
#
# UnicodeDecodeError: 'cp950' codec can't decode byte 0xe2 in position 2950: illegal multibyte sequence
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~\Downloads\20260806_data-main (1)\20260806_data-main\20260730_code\.venv\Lib\site-packages\sklearn\utils\_repr_html\base.py:157, in ReprHTMLMixin._repr_html_inner(self)
#     152 def _repr_html_inner(self):
#     153     """This function is returned by the @property `_repr_html_` to make
#     154     `hasattr(estimator, "_repr_html_") return `True` or `False` depending
#     155     on `get_config()["display"]`.
#     156     """
# --> 157     return self._html_repr()
#
# File ~\Downloads\20260806_data-main (1)\20260806_data-main\20260730_code\.venv\Lib\site-packages\sklearn\utils\_repr_html\estimator.py:564, in estimator_html_repr(estimator)
#     554 _write_estimator_html(
#     555     out,
#     556     estimator,
#    (...)    561     is_fitted_icon=is_fitted_icon,
#     562 )
#     563 with open(str(Path(__file__).parent / "estimator.js"), "r") as f:
# --> 564     script = f.read()
#     566 html_end = (
#     567     f"</div></div><script>{script}"
#     568     f"\nforceTheme('{container_id}');</script></body>"
#     569 )
#     571 out.write(html_end)
#
# UnicodeDecodeError: 'cp950' codec can't decode byte 0xe2 in position 2950: illegal multibyte sequence
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ## 模型評估

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X_test,y_test, cv=10)
                         #,scoring='neg_mean_squared_error'
scores
# Out:
# array([0.8052086 , 0.80011828, 0.80291232, 0.76372096, 0.82041168,
#        0.79669733, 0.81473275, 0.81707941, 0.72696467, 0.79192524])

# %% [markdown]
# ## 平均分數與標準差

# %%
print(f'平均分數: {np.mean(scores)}, 標準差: {np.std(scores)}')
# Out:
# 平均分數: 0.7939771239008935, 標準差: 0.027064199615225742

# %%
#查詢模型特徵的重要程度
print(model.feature_importances_)
# Out:
# [0.5016645  0.06611755 0.04484609 0.02184994 0.02235221 0.13935398
#  0.09896468 0.10485102]

# %% [markdown]
# ## 使用分類模型

# %%
from xgboost import XGBClassifier

X, y = datasets.load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)
model = XGBClassifier()
model.fit(X_train,y_train)
scores = cross_val_score(model, X_test,y_test, cv=10)
print(f'平均分數: {np.mean(scores)}, 標準差: {np.std(scores)}')
# Out:
# 平均分數: 0.9295454545454545, 標準差: 0.08717389711332574

# %%
scores
# Out:
# array([0.91666667, 0.83333333, 1.        , 1.        , 1.        ,
#        1.        , 0.90909091, 0.90909091, 1.        , 0.72727273])
