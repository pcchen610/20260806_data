# %%
from IPython.display import Image

Image("https://hackmd.io/_uploads/Hk_3aVSQfe.png")

# %%
Image("https://hackmd.io/_uploads/rkuA6NBXzg.png")

# %%
Image("https://hackmd.io/_uploads/SJKWANSmMl.png")

# %%
Image("https://hackmd.io/_uploads/ByAQA4rXMl.png")

# %%
Image("https://hackmd.io/_uploads/rJ81JBBmMe.png")

# %%
Image("https://hackmd.io/_uploads/SyzekHr7ze.png")

# %%
Image("https://hackmd.io/_uploads/rkt7kSBXMg.png")
