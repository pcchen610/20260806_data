# %% [markdown]
# # Lesson 01 - 認識資料與 DataFrame

# %%
import numpy as np

a = [5,10,15,20,25,30]
print(a + [100])# 合併新的［］

b = np.array(a)# 將a轉成陣列
print(b + [10])
# Out:
# [5, 10, 15, 20, 25, 30, 100]
# [15 20 25 30 35 40]

# %%
# numpy 要求元素統一類型
import numpy as np

c = np.array([56, True, 36.85,  56, 1]) #"OK",
print(c)
# Out:
# [56.    1.   36.85 56.    1.  ]

# %%
import pandas as pd

d = pd.Series([11,12,13,14,15])#單一欄位
print(d)
print(d + 100)#'OK'
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int64
# 0    111
# 1    112
# 2    113
# 3    114
# 4    115
# dtype: int64

# %%
e = pd.DataFrame({
    'name':['A','B','C','D'],
    'age':[19,22,17,25]
})
print(e)
print(e['age']+5)
print(e)
# Out:
#   name  age
# 0    A   19
# 1    B   22
# 2    C   17
# 3    D   25
# 0    24
# 1    27
# 2    22
# 3    30
# Name: age, dtype: int64
#   name  age
# 0    A   19
# 1    B   22
# 2    C   17
# 3    D   25

# %%
from pathlib import Path
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", 30)
pd.set_option("display.float_format", "{:,.2f}".format)

DATA_DIR_CANDIDATES = [
    Path("../data/raw"),
    Path("data/raw"),
    Path("/content/Py_dataAna/code/data/raw"),
    Path("/content/code/data/raw"),
]

DATA_DIR = next((path for path in DATA_DIR_CANDIDATES if (path / "orders.csv").exists()), None)
if DATA_DIR is None:
    raise FileNotFoundError(
        "找不到 CSV 資料。請確認 code/data/raw/ 內有 orders.csv 等資料檔，"
        "在 Colab 可先上傳整個專案資料夾或掛載 Google Drive。"
    )

print("Using data folder:", DATA_DIR.resolve())
# Out:
# Using data folder: C:\code01\data\raw

# %%
customers = pd.read_csv(DATA_DIR / "customers.csv")#讀入外部資料檔
products = pd.read_csv(DATA_DIR / "products.csv")
orders = pd.read_csv(DATA_DIR / "orders.csv")
order_items = pd.read_csv(DATA_DIR / "order_items.csv")
sessions = pd.read_csv(DATA_DIR / "sessions.csv")
events = pd.read_csv(DATA_DIR / "events.csv")
ab_assignments = pd.read_csv(DATA_DIR / "ab_assignments.csv")

tables = {
    "customers": customers,
    "products": products,
    "orders": orders,
    "order_items": order_items,
    "sessions": sessions,
    "events": events,
    "ab_assignments": ab_assignments,
}
pd.DataFrame(
    [{"table": name, "rows": len(df), "columns": len(df.columns)} for name, df in tables.items()]
)
# Out:
#             table    rows  columns
# 0       customers    2500        5
# 1        products      60        3
# 2          orders   22000        5
# 3     order_items   39627        5
# 4        sessions   70000        7
# 5          events  232067        6
# 6  ab_assignments    2500        3

# %%
import pandas as pd

xx = pd.read_csv('https://opendata.tycg.gov.tw/api/dataset/4e233760-cb9c-4bca-bef2-e14ac80b1667/resource/eff0b4d8-2ef3-49ec-b894-68b92dac23f0/download')
#print(xx)
print(xx.info())#展示資料表訊息
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   區域      10 non-null     str
#  1   公園名稱    10 non-null     str
#  2   特色      10 non-null     str
#  3   設施      10 non-null     str
#  4   地址      10 non-null     str
#  5   地標      10 non-null     str
#  6   停車      5 non-null      str
#  7   廁所      6 non-null      str
# dtypes: str(8)
# memory usage: 772.0 bytes
# None

# %% [markdown]
# ## 看一張表的前幾筆
#
# `head()` 是資料分析最常用的第一步。

# %%
print(customers.head())#檢視資料表的前5筆
print('-'*20)
customers.tail()#檢視資料表的最後5筆
# Out:
#    customer_id signup_date acquisition_channel      city segment
# 0            1  2022-11-29             partner    Taipei  growth
# 1            2  2024-11-11             organic    Tainan  growth
# 2            3  2025-08-17              social   Hsinchu     vip
# 3            4  2025-06-09             organic    Taipei  growth
# 4            5  2024-07-23            referral  Taichung     new
# --------------------
#       customer_id signup_date acquisition_channel       city segment
# 2495         2496  2023-06-30            referral    Taoyuan     vip
# 2496         2497  2025-01-13              social  Kaohsiung  growth
# 2497         2498  2025-05-14             partner   Taichung     vip
# 2498         2499  2023-01-31              social    Hsinchu     new
# 2499         2500  2023-02-12             organic  Kaohsiung     new

# %% [markdown]
# ## 看欄位與資料型態
#
# `info()` 可以幫你快速知道欄位名稱、缺失值與型態。

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      22000 non-null  int64
#  1   customer_id   22000 non-null  int64
#  2   order_date    22000 non-null  str
#  3   status        22000 non-null  str
#  4   payment_type  22000 non-null  str
# dtypes: int64(2), str(3)
# memory usage: 859.5 KB

# %% [markdown]
# ## 小練習
#
# 把下面的 `sessions` 改成 `products`、`events` 或其他資料表，觀察差異。

# %%
table = sessions
display(table.head(10))
print("rows:", len(table))
print("columns:", list(table.columns))
# Out:
#    session_id  customer_id     session_start   device traffic_source  \
# 0           1         2473  2025-08-14T11:02  desktop            sem
# 1           2         2155  2024-02-29T11:56   mobile            sem
# 2           3         2437  2024-11-13T16:23   mobile            sem
# 3           4          164  2024-04-22T16:15   mobile          email
# 4           5         1604  2024-06-15T08:39  desktop         direct
# 5           6         2025  2025-01-03T12:09   mobile            seo
# 6           7         1680  2025-02-01T20:56   mobile            seo
# 7           8         1663  2025-08-17T05:38   mobile          email
# 8           9          684  2025-03-10T13:30   mobile            seo
# 9          10         2418  2025-09-17T03:22  desktop         direct
#
#       campaign experiment_group
# 0         none                B
# 1     retarget                A
# 2         none                B
# 3     retarget                B
# 4         none                A
# ...
